# %%
import glob, os
import seaborn as sns

# %%
data = []
for file in glob.glob("all_stats/static_t_non_obs_stats/*.txt"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]

# %% [markdown]
# Static Threshold Only Non Obs

# %%
sns.distplot(data)

# %%
data = []
for file in glob.glob("all_stats/dynamic_t_non_obs_stats/*.txt"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]

# %% [markdown]
# Dynamic Threshold Only Non Obs

# %%
sns.distplot(data)

# %%
data = []
for file in glob.glob("all_stats/static_t_obs_stats/*.txt"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]

# %% [markdown]
# Static Threshold Only Obs

# %%
sns.distplot(data)

# %%
data = []
for file in glob.glob("all_stats/dynamic_t_obs_stats/*.txt"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]

# %% [markdown]
# Dynamic Threshold Only Obs

# %%
sns.distplot(data)
