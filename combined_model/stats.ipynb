# %%
import glob, os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = []
data_2 = []
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/static_t_non_obs_stats/newStats/static/*"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/dynamic_t_non_obs_stats/newStats/reset/*"):
    f = open(file)
    data_2 += [float(f.read().splitlines()[0])]
sns.kdeplot(data, label="Static", shade=True)
sns.kdeplot(data_2, label="Dynamic", shade=True)
plt.legend()
plt.title("Kernel Density Estimation of the Non-Observable Task")
plt.xlabel("Accuracy")
plt.ylabel("Density")
plt.savefig('reset_non_obs.png', dpi=300)

# %%
data = []
data_2 = []
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/static_t_obs_stats/newStats/static/*"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/dynamic_t_obs_stats/newStats/dynamic/*"):
    f = open(file)
    data_2 += [float(f.read().splitlines()[0])]
sns.kdeplot(data, label="Static", shade=True)
sns.kdeplot(data_2, label="Dynamic", shade=True)
plt.legend()
plt.title("Kernel Density Estimation of the Observable Task")
plt.xlabel("Accuracy")
plt.ylabel("Density")
plt.savefig('reset_obs.png', dpi=300)

# %%
data = []
data_2 = []
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/static_t_combined_stats/static/*"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/dynamic_t_combined_stats/dynamic/*"):
    f = open(file)
    data_2 += [float(f.read().splitlines()[0])]
sns.kdeplot(data, label="Static", shade=True)
sns.kdeplot(data_2, label="Dynamic", shade=True)
plt.legend()
plt.title("Kernel Density Estimation of the Combined Task")
plt.xlabel("Accuracy")
plt.ylabel("Density")
plt.savefig('reset_combined.png', dpi=300)

# %%
data = []
data_2 = []
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/static_t_non_obs_stats/newStats/transfer/*"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/dynamic_t_non_obs_stats/newStats/hrr/*"):
    f = open(file)
    data_2 += [float(f.read().splitlines()[0])]
sns.kdeplot(data, label="Static", shade=True)
sns.kdeplot(data_2, label="Dynamic", shade=True)
plt.legend()
plt.title("Kernel Density Estimation of the Non-Observable Task")
plt.xlabel("Accuracy")
plt.ylabel("Density")
plt.savefig('transfer_non_obs.png', dpi=300)

# %%
data = []
data_2 = []
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/static_t_combined_stats/transfer/*"):
    f = open(file)
    data += [float(f.read().splitlines()[0])]
for file in glob.glob("/home/nibraas_a_khan/Working-Memory-Temporal-Difference/combined_model/all_stats/dynamic_t_combined_stats/transfer/*"):
    f = open(file)
    data_2 += [float(f.read().splitlines()[0])]
sns.kdeplot(data, label="Static", shade=True)
sns.kdeplot(data_2, label="Dynamic", shade=True)
plt.legend()
plt.title("Kernel Density Estimation of the Combined Task")
plt.xlabel("Accuracy")
plt.ylabel("Density")
plt.savefig('transfer_combined.png', dpi=300)
